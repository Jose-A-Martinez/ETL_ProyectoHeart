# %%
import pandas as pd
from scipy.stats import zscore

# %%
# Crear un DataFrame
df = pd.read_csv(r'C:/Users/marti/OneDrive/Escritorio/Henry/Proyecto_Heart/Heart_Disease_Prediction.csv')

# %%
df
# Out:
#        Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# index
# 0       70    1                4  130          322             0            2
# 1       67    0                3  115          564             0            2
# 2       57    1                2  124          261             0            0
# 3       64    1                4  128          263             0            0
# 4       74    0                2  120          269             0            2
# ...    ...  ...              ...  ...          ...           ...          ...
# 265     52    1                3  172          199             1            0
# 266     44    1                2  120          263             0            0
# 267     56    0                2  140          294             0            2
# 268     57    1                4  140          192             0            0
# 269     67    1                4  160          286             0            2
#
# ...

# %%
# Usar la función describe() analizar los datos
df.describe()
# Out:
#             index         Age         Sex  Chest pain type          BP  \
# count  270.000000  270.000000  270.000000       270.000000  270.000000
# mean   134.500000   54.433333    0.677778         3.174074  131.344444
# std     78.086491    9.109067    0.468195         0.950090   17.861608
# min      0.000000   29.000000    0.000000         1.000000   94.000000
# 25%     67.250000   48.000000    0.000000         3.000000  120.000000
# 50%    134.500000   55.000000    1.000000         3.000000  130.000000
# 75%    201.750000   61.000000    1.000000         4.000000  140.000000
# max    269.000000   77.000000    1.000000         4.000000  200.000000
#
#        Cholesterol  FBS over 120  EKG results      Max HR  Exercise angina  \
# count   270.000000    270.000000   270.000000  270.000000       270.000000
# mean    249.659259      0.148148     1.022222  149.677778         0.329630
# std      51.686237      0.355906     0.997891   23.165717         0.470952
# ...

# %%
# CONTROLAR COLUMNAS SELECCIONADAS 
# Seleccionar solo las columnas numéricas
num_cols = ['Age', 'BP', 'Cholesterol', 'Max HR', 'ST depression', 'Number of vessels fluro']

# %%
# Calcular los cuartiles Q1 y Q3 y el rango intercuartil (IQR) solo para las columnas numéricas
Q1 = df[num_cols].quantile(0.25)
Q3 = df[num_cols].quantile(0.75)
IQR = Q3 - Q1

# Identificar los outliers
df_outliers = df[(df[num_cols] < (Q1 - 1.5 * IQR)) | (df[num_cols] > (Q3 + 1.5 * IQR))].dropna(how='all')
df_outliers = df_outliers.align(df, join='right', axis=1)[0]

print(df_outliers)
# Out:
#        Age  Sex  Chest pain type     BP  Cholesterol  FBS over 120  \
# index
# 0      NaN  NaN              NaN    NaN          NaN           NaN
# 1      NaN  NaN              NaN    NaN        564.0           NaN
# 9      NaN  NaN              NaN    NaN        407.0           NaN
# 46     NaN  NaN              NaN    NaN          NaN           NaN
# 48     NaN  NaN              NaN    NaN          NaN           NaN
# 49     NaN  NaN              NaN    NaN          NaN           NaN
# 52     NaN  NaN              NaN    NaN        417.0           NaN
# 58     NaN  NaN              NaN  174.0          NaN           NaN
# 75     NaN  NaN              NaN    NaN          NaN           NaN
# 87     NaN  NaN              NaN  178.0          NaN           NaN
# 101    NaN  NaN              NaN    NaN          NaN           NaN
# 103    NaN  NaN              NaN    NaN          NaN           NaN
# 110    NaN  NaN              NaN  180.0          NaN           NaN
# ...

# %%
# Filtrar solo los valores outliers
outliers = df_outliers.stack().dropna()

# Filtrar solo los valores outliers de columnas especificas
#outliers = df_outliers['BP'].dropna() 
#outliers = df_outliers.loc[:, ['Cholesterol', 'BP']].stack().dropna() 

# Mostrar solo los valores outliers
print(outliers)
# Out:
# index
# 0      Number of vessels fluro      3.0
# 1      Cholesterol                564.0
# 9      Cholesterol                407.0
#        Number of vessels fluro      3.0
# 46     Number of vessels fluro      3.0
# 48     Number of vessels fluro      3.0
# 49     Number of vessels fluro      3.0
# 52     Cholesterol                417.0
# 58     BP                         174.0
# 75     Number of vessels fluro      3.0
# 87     BP                         178.0
#        ST depression                4.2
# 101    Max HR                      71.0
# 103    Number of vessels fluro      3.0
# 110    BP                         180.0
# 117    BP                         200.0
# 120    Number of vessels fluro      3.0
# 144    BP                         192.0
# 156    ST depression                5.6
# 159    BP                         178.0
# 165    BP                         180.0
# 171    Number of vessels fluro      3.0
# 175    Number of vessels fluro      3.0
# ...

# %%
# Calcular el puntaje z para cada valor en las columnas numéricas seleccionadas
z_scores = df[num_cols].apply(zscore)

# Eliminar los valores que tengan un puntaje z mayor a 3 o menor a -3
df_clean = df[(z_scores < 3).all(axis=1) & (z_scores > -3).all(axis=1)]

# %%
df_clean
# Out:
#        Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# index
# 0       70    1                4  130          322             0            2
# 2       57    1                2  124          261             0            0
# 3       64    1                4  128          263             0            0
# 4       74    0                2  120          269             0            2
# 5       65    1                4  120          177             0            0
# ...    ...  ...              ...  ...          ...           ...          ...
# 265     52    1                3  172          199             1            0
# 266     44    1                2  120          263             0            0
# 267     56    0                2  140          294             0            2
# 268     57    1                4  140          192             0            0
# 269     67    1                4  160          286             0            2
#
# ...
